# %% [markdown]
# ## Usandod VGG16 para Classificar Porcos

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
modelo = VGG16(weights='imagenet')
# Out:
# WARNING:tensorflow:From /home/juan/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 465518592/553467096 [========================>.....] - ETA: 20s

# %%
# !wget -c "http://revistagloborural.globo.com/Revista/GloboRural/foto/0,,43969382,00.jpg" -o pigs.jpg

# %% [markdown]
# ## Imagem de porcos

# %%
from IPython.display import Image
Image("pigsss.jpg")

# %%
# !ls
# Out:
# pigsss.jpg  sample_data

# %%
imagem   = 'pigsss.jpg'
target   =   image.load_img(imagem, target_size=(224, 224))
img_data = image.img_to_array(target)
img_data = np.expand_dims(img_data, axis=0)
img_data = preprocess_input(img_data)

# %%
preds = modelo.predict(img_data)
for p in decode_predictions(preds, top=10)[0]:
  print(p)
# Out:
# ('n02395406', 'hog', 0.729229)
# ('n01877812', 'wallaby', 0.23026198)
# ('n02091244', 'Ibizan_hound', 0.025602067)
# ('n02114548', 'white_wolf', 0.0054478142)
# ('n02412080', 'ram', 0.002172356)
# ('n02396427', 'wild_boar', 0.0020817975)
# ('n01855672', 'goose', 0.0009570904)
# ('n04604644', 'worm_fence', 0.000649106)
# ('n02326432', 'hare', 0.00034365174)
# ('n02105412', 'kelpie', 0.00030545698)
